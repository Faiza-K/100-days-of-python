# %% [markdown]
# <a href="https://colab.research.google.com/github/Faiza-K/100-days-of-python/blob/main/Data_Scraping_for_container_agent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from bs4 import BeautifulSoup
import requests
import re

key_word = ' history'
url = 'https://www.bic-code.org/search/bic-codes/country/all/results/4000'

# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
rca_data= pd.ExcelFile("/content/drive/MyDrive/Container  Owners Details/Book3.xlsx")
rca_data2= pd.ExcelFile('/content/drive/MyDrive/Container  Owners Details/Code of Container BIC website.xlsx')
#rca_data2= pd.ExcelFile('/content/drive/MyDrive/Container  Owners Details/PrefixData H1.xlsx')

# %%
df1= pd.read_excel(rca_data, 'Column1')
df3= pd.read_excel(rca_data, 'Column2')

# %%
df2=pd.read_excel(rca_data2, 'Sheet1')
df2
# Out:
#       Code                                      Company
# 0     AAAU                ASIA CONTAINER LEASING CO LTD
# 1     AABU                    ALLTAINER VIETNAM CO, LTD
# 2     AACU                   ACE GLOBAL LINES DWC - LLC
# 3     AAFU     BUNDESMINISTERIUM FUR LANDESVERTEIDIGUNG
# 4     AAGU          ROLLS-ROYCE SOLUTIONS RUHSTORF GMBH
# ...    ...                                          ...
# 3628  ZWFU                    ZIM WORLD FREIGHT PVT LTD
# 3629  ZWIU                               V+A ZWISSIG SA
# 3630  ZXJU  QINGDAO RUIJUNYUAN INDUSTRY TRADE CO., LTD.
# 3631  ZYCU            ZHONGYI CONTAINER LEASING LIMITED
# 3632  ZYMU                    ZIJDERHAND MOERKAPELLE BV
#
# [3633 rows x 2 columns]

# %%
df1.head()
# Out:
#    Code  Company
# 0  EMKU      NaN
# 1  EMKU      NaN
# 2  EMKU      NaN
# 3  EMKU      NaN
# 4  OOCU      NaN

# %%
merge_data= pd.merge(df2, df1,on=['Code'], how='right')
merge_data
# Out:
#        Code Company                            Company_x
# 0      EMKU     NaN                EMKAY LINES (PVT) LTD
# 1      EMKU     NaN                EMKAY LINES (PVT) LTD
# 2      EMKU     NaN                EMKAY LINES (PVT) LTD
# 3      EMKU     NaN                EMKAY LINES (PVT) LTD
# 4      OOCU     NaN  ORIENT OVERSEAS CONTAINER LINE LTD.
# ...     ...     ...                                  ...
# 15201  GATU     NaN   TEXTAINER EQUIPMENT MANAGEMENT LTD
# 15202  DVRU     NaN                              CMA-CGM
# 15203  DVRU     NaN                              CMA-CGM
# 15204  WSCU     NaN                   CARU CONTAINERS BV
# 15205  TCLU     NaN   TRITON CONTAINER INTERNATIONAL LTD
#
# [15206 rows x 3 columns]

# %%
merge_data.to_excel('column1.xlsx')

# %% [markdown]
# #Column2

# %%
merge_data= pd.merge(df2, df3,on=['Code'], how='right')
merge_data
# Out:
#        Code                           Company_x  Company_y
# 0      TEMU  TEXTAINER EQUIPMENT MANAGEMENT LTD        NaN
# 1      TEMU  TEXTAINER EQUIPMENT MANAGEMENT LTD        NaN
# 2      TEMU  TEXTAINER EQUIPMENT MANAGEMENT LTD        NaN
# 3      TEMU  TEXTAINER EQUIPMENT MANAGEMENT LTD        NaN
# 4       NaN                                 NaN        NaN
# ...     ...                                 ...        ...
# 15172   NaN                                 NaN        NaN
# 15173   NaN                                 NaN        NaN
# 15174   NaN                                 NaN        NaN
# 15175   NaN                                 NaN        NaN
# 15176  TCNU  TRITON CONTAINER INTERNATIONAL LTD        NaN
#
# [15177 rows x 3 columns]

# %%
merge_data.to_excel('column2.xlsx')

# %% [markdown]
# #Column3

# %%
dataFrame3= pd.read_excel(rca_data, 'Column3')

merge_data3= pd.merge(df2, dataFrame3,on=['Code'], how='right')
merge_data3
# Out:
#        Code                           Company_x  Company_y
# 0       NaN                                 NaN        NaN
# 1       NaN                                 NaN        NaN
# 2       NaN                                 NaN        NaN
# 3       NaN                                 NaN        NaN
# 4       NaN                                 NaN        NaN
# ...     ...                                 ...        ...
# 15172   NaN                                 NaN        NaN
# 15173   NaN                                 NaN        NaN
# 15174   NaN                                 NaN        NaN
# 15175   NaN                                 NaN        NaN
# 15176  TCNU  TRITON CONTAINER INTERNATIONAL LTD        NaN
#
# [15177 rows x 3 columns]

# %%
merge_data3.to_excel('column3.xlsx')

# %% [markdown]
# #Column4

# %%
dataFrame4= pd.read_excel(rca_data, 'Column4')

merge_data4= pd.merge(df2, dataFrame4,on=['Code'], how='right')
merge_data4
# Out:
#        Code                           Company_x  Company_y
# 0       NaN                                 NaN        NaN
# 1       NaN                                 NaN        NaN
# 2       NaN                                 NaN        NaN
# 3       NaN                                 NaN        NaN
# 4       NaN                                 NaN        NaN
# ...     ...                                 ...        ...
# 15172   NaN                                 NaN        NaN
# 15173   NaN                                 NaN        NaN
# 15174   NaN                                 NaN        NaN
# 15175   NaN                                 NaN        NaN
# 15176  TCNU  TRITON CONTAINER INTERNATIONAL LTD        NaN
#
# [15177 rows x 3 columns]

# %%
merge_data4.to_excel('column4.xlsx')

# %% [markdown]
# #Column5

# %%
dataFrame5= pd.read_excel(rca_data, 'Column5')

merge_data5= pd.merge(df2, dataFrame5,on=['Code'], how='right')
merge_data5
# Out:
#        Code                           Company_x  Company_y
# 0       NaN                                 NaN        NaN
# 1       NaN                                 NaN        NaN
# 2       NaN                                 NaN        NaN
# 3       NaN                                 NaN        NaN
# 4       NaN                                 NaN        NaN
# ...     ...                                 ...        ...
# 15172   NaN                                 NaN        NaN
# 15173   NaN                                 NaN        NaN
# 15174   NaN                                 NaN        NaN
# 15175   NaN                                 NaN        NaN
# 15176  TCNU  TRITON CONTAINER INTERNATIONAL LTD        NaN
#
# [15177 rows x 3 columns]

# %%
merge_data5.to_excel('column5.xlsx')

# %% [markdown]
# #Column6

# %%
dataFrame6= pd.read_excel(rca_data, 'Column6')

merge_data6= pd.merge(df2, dataFrame6,on=['Code'], how='right')
merge_data6
# Out:
#        Code                             Company  \
# 0       NaN                                 NaN
# 1       NaN                                 NaN
# 2       NaN                                 NaN
# 3       NaN                                 NaN
# 4       NaN                                 NaN
# ...     ...                                 ...
# 15172   NaN                                 NaN
# 15173   NaN                                 NaN
# 15174   NaN                                 NaN
# 15175   NaN                                 NaN
# 15176  TRLU  TRITON CONTAINER INTERNATIONAL LTD
#
#                                 Company_x
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ...                                   ...
# 15172                                 NaN
# ...

# %%
merge_data6.to_excel('column6.xlsx')

# %% [markdown]
# #Column7

# %%
dataFrame7= pd.read_excel(rca_data, 'Column7')

merge_data7= pd.merge(df2, dataFrame7,on=['Code'], how='right')
merge_data7
# Out:
#        Code                                 Company_x  Company_y
# 0       NaN                                       NaN        NaN
# 1       NaN                                       NaN        NaN
# 2       NaN                                       NaN        NaN
# 3       NaN                                       NaN        NaN
# 4       NaN                                       NaN        NaN
# ...     ...                                       ...        ...
# 14869   NaN                                       NaN        NaN
# 14870  FFAU  FLORENS ASSET MANAGEMENT COMPANY LIMITED        NaN
# 14871   NaN                                       NaN        NaN
# 14872   NaN                                       NaN        NaN
# 14873  FFAU  FLORENS ASSET MANAGEMENT COMPANY LIMITED        NaN
#
# [14874 rows x 3 columns]

# %%
merge_data7.to_excel('column7.xlsx')

# %% [markdown]
# #Column8

# %%
dataFrame8= pd.read_excel(rca_data, 'Column8')

merge_data8= pd.merge(df2, dataFrame8,on=['Code'], how='right')
merge_data8
# Out:
#        Code                                 Company_x  Company_y
# 0       NaN                                       NaN        NaN
# 1       NaN                                       NaN        NaN
# 2       NaN                                       NaN        NaN
# 3       NaN                                       NaN        NaN
# 4       NaN                                       NaN        NaN
# ...     ...                                       ...        ...
# 14869   NaN                                       NaN        NaN
# 14870  FFAU  FLORENS ASSET MANAGEMENT COMPANY LIMITED        NaN
# 14871   NaN                                       NaN        NaN
# 14872   NaN                                       NaN        NaN
# 14873  REGU                        RCL FEEDER PTE LTD        NaN
#
# [14874 rows x 3 columns]

# %%
merge_data8.to_excel('column8.xlsx')

# %%
merge_data9.to_excel('column9.xlsx')

# %% [markdown]
# #Column9

# %%
dataFrame9= pd.read_excel(rca_data, 'Column9')

merge_data9= pd.merge(df2, dataFrame9,on=['Code'], how='right')
merge_data9
# Out:
#        Code                                 Company_x  Company_y
# 0       NaN                                       NaN        NaN
# 1       NaN                                       NaN        NaN
# 2       NaN                                       NaN        NaN
# 3       NaN                                       NaN        NaN
# 4       NaN                                       NaN        NaN
# ...     ...                                       ...        ...
# 14866   NaN                                       NaN        NaN
# 14867   NaN                                       NaN        NaN
# 14868   NaN                                       NaN        NaN
# 14869   NaN                                       NaN        NaN
# 14870  FFAU  FLORENS ASSET MANAGEMENT COMPANY LIMITED        NaN
#
# [14871 rows x 3 columns]

# %% [markdown]
# #Column10

# %%
dataFrame10= pd.read_excel(rca_data, 'Column10')

merge_data10= pd.merge(df2, dataFrame10, on=['Code'], how='right')
merge_data10
# Out:
#        Code                               Company_x  Company_y
# 0       NaN                                     NaN        NaN
# 1       NaN                                     NaN        NaN
# 2       NaN                                     NaN        NaN
# 3       NaN                                     NaN        NaN
# 4       NaN                                     NaN        NaN
# ...     ...                                     ...        ...
# 14866   NaN                                     NaN        NaN
# 14867   NaN                                     NaN        NaN
# 14868   NaN                                     NaN        NaN
# 14869   NaN                                     NaN        NaN
# 14870  KMTU  KOREA MARINE TRANSPORT CO / E. C. TEAM        NaN
#
# [14871 rows x 3 columns]

# %%
merge_data10.to_excel('column10.xlsx')

# %% [markdown]
# #Column11

# %%
dataFrame11= pd.read_excel(rca_data, "Column11")

# %%
merge_data11= pd.merge(df2, dataFrame11, on=['Code'], how='right')
merge_data11
# Out:
#        Code  Company_x  Company_y
# 0       NaN        NaN        NaN
# 1       NaN        NaN        NaN
# 2       NaN        NaN        NaN
# 3       NaN        NaN        NaN
# 4       NaN        NaN        NaN
# ...     ...        ...        ...
# 14866   NaN        NaN        NaN
# 14867   NaN        NaN        NaN
# 14868   NaN        NaN        NaN
# 14869   NaN        NaN        NaN
# 14870  SEGU  SEACO SRL        NaN
#
# [14871 rows x 3 columns]

# %%
merge_data11.to_excel('column11.xlsx')

# %% [markdown]
# # Column12

# %%
dataFrame12= pd.read_excel(rca_data, 'Column12')

# %%
merge_data12 = pd.merge(df2, dataFrame12, on= ["Code"], how= 'right')
merge_data12
# Out:
#        Code                           Company_x  Company_y
# 0       NaN                                 NaN        NaN
# 1       NaN                                 NaN        NaN
# 2       NaN                                 NaN        NaN
# 3       NaN                                 NaN        NaN
# 4       NaN                                 NaN        NaN
# ...     ...                                 ...        ...
# 14866   NaN                                 NaN        NaN
# 14867   NaN                                 NaN        NaN
# 14868   NaN                                 NaN        NaN
# 14869   NaN                                 NaN        NaN
# 14870  TEMU  TEXTAINER EQUIPMENT MANAGEMENT LTD        NaN
#
# [14871 rows x 3 columns]

# %%
merge_data12.to_excel('column12.xlsx')
